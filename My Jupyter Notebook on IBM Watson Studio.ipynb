# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio (I am Sharing to Github). <h1>

# %% [markdown]
# <b> Sourabh Malhotra <b>
#
#
#
#  I am an administrator who wants to work in Public Policy Research, for a reputable Research Institute.

# %% [markdown]
# <em> I am interested in Data Science because, as a Social Scientist, I believe big data is an unvoidable insight that needs to be acknowledged and made useful. I believe it should be helpful for social network analysis, as well as marketing and consumer behaviour. <em>

# %% [markdown]
# <h3> In the cell, below, you will see a simple multiplicaion, with an output: <h3>

# %%
7*8
# Out:
# [1] 56

# %% [markdown]
# ----
#
# - one
# - two
# - three
# - four
# - five
# - six
#
#
# |<b>Markdown<b>|<b>Less<b>|<b>Pretty<b>|
# | --- | --- | --- |
# |<em>Still<em> |renders   |<b>nicely<b>|
# |1             |2         |3           |
#
#
# www.ibm.com
